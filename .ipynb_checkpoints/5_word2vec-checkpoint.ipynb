# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %matplotlib inline

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
    
  assert num_skips <= 2 * skip_window

  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)

  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)

  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ] #make sure we don't pick the word itself as a label
    for j in range(num_skips): #num_skips = the number of times we want to use the same input to generate a label
      #make sure we don't pick the same label twice for a word
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'term', 'a', 'originated', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default():

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1).minimize(loss)

    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# WARNING:tensorflow:From /home/tzeny/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/ops/nn_impl.py:1344: softmax_cross_entropy_with_logits (from tensorflow.python.ops.nn_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
#
# Future major versions of TensorFlow will allow gradients to flow
# into the labels input on backprop by default.
#
# See @{tf.nn.softmax_cross_entropy_with_logits_v2}.

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(batch_size, num_skips, skip_window)
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
            
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.451153
# Nearest to for: earnest, dachshunds, adherents, ubu, abroad, change, wark, darcy,
# Nearest to three: whistler, duma, durant, plagiarized, papeete, crime, zs, logographic,
# Nearest to history: envelopes, separates, mvp, anointing, oddly, morbidity, grandparents, reliefs,
# Nearest to states: anything, ap, inadequacy, antiprotons, alder, disputed, terrorists, anthologies,
# Nearest to on: smalltalk, surrenders, jabal, layouts, practice, huntley, edict, kees,
# Nearest to that: acrylic, parma, nova, bret, reichstag, archangels, realistically, ambassadors,
# Nearest to when: garnet, lafur, aunts, steeped, joaqu, sextilis, sabres, freethought,
# Nearest to world: rings, reproduce, loaded, dabbled, devise, symbolically, timecode, career,
# Nearest to be: confessional, reckoned, swamped, believed, appalachians, geotechnical, mandelstam, interceptor,
# Nearest to by: gmt, harnessed, playfair, bumped, adhemar, petrol, hematite, chronicle,
# Nearest to seven: aryans, tracey, alcs, inductees, lizzy, directory, alphabet, chess,
# Nearest to their: routinely, feynman, const, rhyming, madeira, functional, freshly, tahoe,
# Nearest to other: chopin, mana, ternary, bhumi, mitterrand, caveats, architecture, localised,
# Nearest to up: hillary, moa, insert, incompressible, uzziah, rest, behavioral, lent,
# Nearest to an: indentured, economically, chorale, appeals, italy, alvarado, xb, transfer,
# Nearest to as: forbade, shiga, relation, bardot, synchronised, reverse, magnetron, rey,
# Average loss at step 2000: 4.365170
# Average loss at step 4000: 3.868837
# Average loss at step 6000: 3.785595
# Average loss at step 8000: 3.687906
# Average loss at step 10000: 3.614165
# Nearest to for: in, of, with, qassam, millisecond, joshi, afford, susanna,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to history: mvp, anointing, envelopes, woodstock, seek, morbidity, hanford, muslims,
# Nearest to states: anything, antiprotons, sheppard, engagement, disputed, gin, decree, alder,
# Nearest to on: in, with, camus, mendeleev, at, from, by, ktav,
# Nearest to that: it, what, which, nova, penang, anatomical, this, who,
# Nearest to when: sabres, zach, empirically, canberra, yousef, nor, doc, phoned,
# Nearest to world: reproduce, symbolically, dabbled, rings, career, mentality, wound, atkins,
# Nearest to be: have, skid, was, alston, electrification, according, by, been,
# Nearest to by: elamite, was, siemens, eliyahu, perceiving, be, on, with,
# Nearest to seven: eight, six, nine, five, three, four, zero, two,
# Nearest to their: his, its, feynman, keeling, the, map, this, babylonians,
# Nearest to other: chopin, college, dilemmas, ghiorso, permissive, people, harness, ethertype,
# Nearest to up: lent, incompressible, insert, cnr, incapacitated, uzziah, hala, moa,
# Nearest to an: transfer, minimally, postings, metrology, indentured, the, xb, netscape,
# Nearest to as: betraying, waging, relation, lj, harpsichord, shiga, prostaglandins, by,
# Average loss at step 12000: 3.602952
# Average loss at step 14000: 3.570389
# Average loss at step 16000: 3.415110
# Average loss at step 18000: 3.454208
# Average loss at step 20000: 3.541329
# Nearest to for: with, of, in, by, granary, showed, millisecond, cameras,
# Nearest to three: four, seven, five, six, two, zero, eight, nine,
# Nearest to history: bourbon, mvp, vigorous, lillee, barbuda, neighbouring, day, noor,
# Nearest to states: anything, antiprotons, decree, sheppard, engagement, crony, alder, mull,
# Nearest to on: in, upon, at, multiverse, camus, between, into, containing,
# Nearest to that: which, what, but, penang, however, who, this, anatomical,
# Nearest to when: if, but, zach, after, during, though, nor, empirically,
# Nearest to world: reproduce, symbolically, rings, career, dabbled, wound, u, largest,
# Nearest to be: have, been, skid, was, alston, being, were, by,
# Nearest to by: elamite, into, be, perceiving, with, for, without, in,
# Nearest to seven: eight, six, nine, three, four, five, zero, two,
# Nearest to their: his, its, the, her, this, them, any, angers,
# Nearest to other: many, are, ethertype, woven, these, some, different, vowels,
# Nearest to up: lent, cnr, insert, incompressible, incapacitated, gumbo, ain, bh,
# Nearest to an: the, transfer, metrology, minimally, bipartite, kx, netscape, bards,
# Nearest to as: hesperides, psychometrics, shiga, waging, bukovina, relation, infanta, safeties,
# Average loss at step 22000: 3.505644
# Average loss at step 24000: 3.487030
# Average loss at step 26000: 3.480335
# Average loss at step 28000: 3.483279
# Average loss at step 30000: 3.504297
# Nearest to for: bootp, with, on, susanna, of, when, after, granary,
# Nearest to three: four, five, seven, eight, six, two, zero, nine,
# Nearest to history: barbuda, vigorous, lillee, bourbon, census, noor, neighbouring, envelopes,
# Nearest to states: decree, antiprotons, anything, euphoric, sheppard, crony, engagement, nations,
# Nearest to on: in, upon, into, between, within, about, from, for,
# Nearest to that: which, what, this, listens, if, anatomical, however, nova,
# Nearest to when: if, where, after, before, during, but, though, yousef,
# Nearest to world: reproduce, symbolically, cavendish, largest, asymptotes, wound, mentality, career,
# Nearest to be: been, have, skid, were, refer, provide, become, was,
# Nearest to by: under, was, kemerovo, in, hanns, pins, from, hypnosis,
# Nearest to seven: eight, four, six, five, nine, three, zero, two,
# Nearest to their: its, his, the, her, any, our, some, these,
# Nearest to other: different, these, ethertype, are, various, some, many, cryptanalysis,
# Nearest to up: lent, gumbo, cnr, him, incapacitated, insert, over, ain,
# Nearest to an: transfer, xb, postings, bards, chairs, contraceptives, indentured, emirs,
# Nearest to as: shiga, signalling, mold, waging, neisse, safeties, bukovina, tributary,
# Average loss at step 32000: 3.504928
# Average loss at step 34000: 3.493783
# Average loss at step 36000: 3.454357
# Average loss at step 38000: 3.306584
# Average loss at step 40000: 3.428662
# Nearest to for: with, floss, after, to, in, technicality, bootp, while,
# Nearest to three: four, two, five, seven, six, eight, nine, zero,
# Nearest to history: barbuda, neighbouring, hanford, heterogeneous, virginals, bourbon, thy, noor,
# Nearest to states: nations, antiprotons, decree, sheppard, crony, engagement, debuts, anything,
# Nearest to on: upon, about, between, at, during, since, isaurian, in,
# Nearest to that: which, what, this, however, if, bidding, adventist, empty,
# Nearest to when: where, if, before, but, after, since, though, during,
# Nearest to world: career, symbolically, gol, legacies, gesserit, largest, u, rings,
# Nearest to be: been, have, continue, was, refer, being, is, according,
# Nearest to by: perceiving, dmd, hanns, mailing, be, for, with, playfair,
# Nearest to seven: eight, six, five, nine, four, three, zero, two,
# Nearest to their: his, its, her, the, some, any, our, these,
# Nearest to other: different, various, including, breakthrough, some, procellariiformes, capitan, such,
# Nearest to up: out, cnr, lent, gumbo, him, waveform, back, off,
# Nearest to an: transfer, postings, xb, contraceptives, honorum, jamaat, kx, simd,
# Nearest to as: jezreel, prostaglandins, papyri, waging, convexity, babi, tributary, drachmae,
# Average loss at step 42000: 3.435774
# Average loss at step 44000: 3.454761
# Average loss at step 46000: 3.453489
# Average loss at step 48000: 3.356520
# Average loss at step 50000: 3.381845
# Nearest to for: while, after, susanna, bootp, pinnacles, granary, by, floss,
# Nearest to three: seven, four, six, eight, five, nine, two, zero,
# Nearest to history: virginals, heterogeneous, neighbouring, barbuda, thy, bourbon, insemination, list,
# Nearest to states: nations, engagement, kingdom, antiprotons, crony, decree, anything, debuts,
# Nearest to on: upon, in, at, under, throughout, lecompton, within, across,
# Nearest to that: which, however, what, adventist, organometallic, this, feuding, schmitz,
# Nearest to when: if, after, where, before, during, while, but, though,
# Nearest to world: gol, largest, gesserit, sedan, symbolically, legacies, career, lyon,
# Nearest to be: been, was, have, become, refer, is, being, were,
# Nearest to by: under, with, hanns, through, siemens, during, hypnosis, against,
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to their: its, his, her, the, our, any, some, these,
# Nearest to other: different, various, many, fertile, like, tumultuous, these, breakthrough,
# Nearest to up: out, cnr, them, off, lent, back, him, down,
# Nearest to an: transfer, honorum, postings, indentured, bards, contraceptives, kx, this,
# Nearest to as: mold, after, became, shiga, rapp, secondly, harpsichord, waging,
# Average loss at step 52000: 3.438372
# Average loss at step 54000: 3.427757
# Average loss at step 56000: 3.434960
# Average loss at step 58000: 3.399439
# Average loss at step 60000: 3.394243
# Nearest to for: when, including, of, without, nicholson, granary, if, technicality,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to history: philosophy, list, barbuda, csa, insemination, virginals, athenian, governance,
# Nearest to states: nations, kingdom, engagement, decree, euphoric, crony, elections, colonies,
# Nearest to on: upon, within, through, under, in, spiral, stepfather, into,
# Nearest to that: which, this, however, what, there, it, snub, where,
# Nearest to when: if, after, before, where, during, while, although, though,
# Nearest to world: symbolically, legacies, largest, gol, theoretically, olympics, qa, achaemenid,
# Nearest to be: been, was, being, continue, become, have, is, are,
# Nearest to by: through, under, perceiving, as, be, with, siemens, malpighi,
# Nearest to seven: eight, four, six, nine, five, three, zero, one,
# Nearest to their: its, his, her, the, our, some, these, prickly,
# Nearest to other: different, various, several, many, including, some, fertile, these,
# Nearest to up: out, off, cnr, down, them, back, lent, waveform,
# Nearest to an: transfer, contraceptives, indentured, jamaat, pars, kx, postings, emirs,
# Nearest to as: waging, mold, copps, carver, when, by, slams, planks,
# Average loss at step 62000: 3.239562
# Average loss at step 64000: 3.251003
# Average loss at step 66000: 3.407028
# Average loss at step 68000: 3.398654
# Average loss at step 70000: 3.359695
# Nearest to for: while, without, including, in, after, if, blank, pinnacles,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to history: philosophy, list, period, noor, insemination, athenian, csa, plesiosaur,
# Nearest to states: nations, kingdom, countries, engagement, state, colonies, anything, rimet,
# Nearest to on: upon, within, through, in, spiral, ora, under, inquisitor,
# Nearest to that: which, however, what, this, but, snub, adventist, where,
# Nearest to when: if, where, before, while, after, though, because, however,
# Nearest to world: largest, gesserit, lyon, theoretically, sedan, olympics, symbolically, legacies,
# Nearest to be: been, were, is, become, was, being, are, have,
# Nearest to by: through, without, rioters, in, was, be, from, hanns,
# Nearest to seven: eight, six, four, nine, five, three, one, zero,
# Nearest to their: its, his, her, the, some, our, these, any,
# Nearest to other: different, various, including, vah, many, these, chisel, procellariiformes,
# Nearest to up: off, out, them, down, back, waveform, scores, cnr,
# Nearest to an: transfer, contraceptives, pars, another, nematic, jamaat, barbagia, indentured,
# Nearest to as: waging, mold, papyri, singleton, like, healthy, bukovina, became,
# Average loss at step 72000: 3.377721
# Average loss at step 74000: 3.348246
# Average loss at step 76000: 3.325461
# Average loss at step 78000: 3.352633
# Average loss at step 80000: 3.377958
# Nearest to for: logos, dkk, bootp, technicality, granary, while, floss, pinnacles,
# Nearest to three: four, six, five, eight, seven, two, nine, zero,
# Nearest to history: philosophy, mmol, list, period, lubricating, rooms, bunt, noor,
# Nearest to states: nations, kingdom, countries, elections, state, colonies, enterprising, rimet,
# Nearest to on: upon, in, through, at, during, under, within, ora,
# Nearest to that: which, however, this, what, where, anatomical, adventist, cowardice,
# Nearest to when: if, before, after, though, while, where, during, although,
# Nearest to world: largest, sedan, lyon, country, theoretically, gesserit, hungarian, olympics,
# Nearest to be: been, have, become, being, were, refer, is, are,
# Nearest to by: through, newly, under, when, infernal, bumped, hanns, without,
# Nearest to seven: six, eight, five, four, nine, three, zero, one,
# Nearest to their: its, his, her, our, the, some, my, your,
# Nearest to other: various, different, fertile, including, others, phages, glues, individual,
# Nearest to up: out, off, down, them, back, him, cnr, away,
# Nearest to an: transfer, pars, kx, contraceptives, xb, bards, dubliners, emirs,
# Nearest to as: waging, babi, citing, after, rapp, metalwork, including, shiga,
# Average loss at step 82000: 3.405594
# Average loss at step 84000: 3.416532
# Average loss at step 86000: 3.389732
# Average loss at step 88000: 3.351199
# Average loss at step 90000: 3.369182
# Nearest to for: including, of, bootp, floss, hazel, after, without, when,
# Nearest to three: four, five, two, seven, eight, six, nine, zero,
# Nearest to history: list, philosophy, mmol, view, period, peerage, virginals, lubricating,
# Nearest to states: kingdom, nations, elections, fantagraphics, enterprising, countries, observers, colonies,
# Nearest to on: upon, at, under, in, ora, about, galactic, walruses,
# Nearest to that: which, however, what, adventist, but, extractive, snub, furthermore,
# Nearest to when: if, before, after, while, though, where, during, although,
# Nearest to world: achaemenid, benevolent, gesserit, lyon, actual, theoretically, misty, westerly,
# Nearest to be: been, have, become, was, refer, being, were, is,
# Nearest to by: through, when, without, under, newly, infernal, with, and,
# Nearest to seven: eight, four, five, six, nine, three, one, zero,
# Nearest to their: its, his, her, our, whose, some, the, both,
# Nearest to other: various, different, individual, including, ethnic, exciting, berber, glues,
# Nearest to up: out, off, down, them, back, him, cnr, away,
# Nearest to an: pars, indentured, falsifiability, kx, contraceptives, jamaat, humanae, transfer,
# Nearest to as: mold, babi, waging, canadiens, adlai, rapp, osip, keswick,
# Average loss at step 92000: 3.402000
# Average loss at step 94000: 3.249485
# Average loss at step 96000: 3.357014
# Average loss at step 98000: 3.245677
# Average loss at step 100000: 3.354474
# Nearest to for: when, against, if, floss, without, after, logos, before,
# Nearest to three: five, four, seven, six, eight, two, zero, nine,
# Nearest to history: list, mmol, virginals, lubricating, thrusts, tribunals, philosophy, stunt,
# Nearest to states: nations, kingdom, elections, observers, enterprising, countries, rimet, state,
# Nearest to on: upon, through, in, at, within, under, into, ora,
# Nearest to that: which, however, what, this, anatomical, putin, who, listens,
# Nearest to when: if, while, before, though, where, after, although, because,
# Nearest to world: lans, country, gesserit, u, lyon, sedan, misty, benevolent,
# Nearest to be: been, being, become, have, are, refer, were, is,
# Nearest to by: through, without, when, against, from, been, hypnosis, under,
# Nearest to seven: eight, six, four, five, nine, three, zero, two,
# Nearest to their: its, his, her, our, the, your, whose, some,
# Nearest to other: various, individual, different, others, including, glues, fertile, frigate,
# Nearest to up: out, off, down, him, them, back, turn, cnr,
# Nearest to an: transfer, pars, kx, nematic, another, indentured, hazard, dubliners,
# Nearest to as: adlai, stargate, waging, babi, shiga, mold, after, rapp,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cow(batch_size, R):
    global data_index
    buffer_index = 0
    
    assert R > 0

    batch = np.ndarray(shape=(batch_size, R*2), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    data_len = batch_size + 4
    buffer = collections.deque(maxlen=data_len)
    
    #fill our buffer with enough entries from the data input
    for _ in range(data_len):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
        
    for i in range(batch_size):
        target = R  # target label at the center of the buffer
        for j in range(2*R+1):
            if j==target:#skip over the middle word
                continue
            if j<target:#set first R words
                batch[i][j] = buffer[i + j]
            else:#the next R words will be offset by 1 in the vector
                batch[i][j-1] = buffer[i + j]
        labels[i] = buffer[i+target];
    return batch, labels

print('data encoded: ', data[:16])
print('data:', [reverse_dictionary[di] for di in data[:16]])

for R in range(1,3):
    data_index = 0
    batch, labels = generate_batch_cow(batch_size=8, R=R)
    print('\nwith R= %d: ' % (R))
    for j in range(0,batch.shape[0]):
        print('    batch ',j,': ', [reverse_dictionary[bi] for bi in batch[:][j]])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data encoded:  [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156, 128, 742, 477, 10572, 134, 1]
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with R= 1:
#     batch  0 :  ['anarchism', 'as']
#     batch  1 :  ['originated', 'a']
#     batch  2 :  ['as', 'term']
#     batch  3 :  ['a', 'of']
#     batch  4 :  ['term', 'abuse']
#     batch  5 :  ['of', 'first']
#     batch  6 :  ['abuse', 'used']
#     batch  7 :  ['first', 'against']
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with R= 2:
#     batch  0 :  ['anarchism', 'originated', 'a', 'term']
#     batch  1 :  ['originated', 'as', 'term', 'of']
#     batch  2 :  ['as', 'a', 'of', 'abuse']
#     batch  3 :  ['a', 'term', 'abuse', 'first']
#     batch  4 :  ['term', 'of', 'first', 'used']
#     batch  5 :  ['of', 'abuse', 'used', 'against']
#     batch  6 :  ['abuse', 'first', 'against', 'early']
#     batch  7 :  ['first', 'used', 'early', 'working']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
cbow_r = 2#how many words in the past and future do we retain
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.ndarray(shape=(valid_size, cbow_r*2), dtype=np.int32)
valid_labels = np.empty(shape=(valid_size), dtype=np.int32)
num_sampled = 64 # Number of negative examples to sample.


for key,i in enumerate(random.sample(range(valid_window), valid_size)):
    target = cbow_r  # target label at the center of the buffer
    for j in range(2*cbow_r+1):
        if j==target:#skip over the middle word
            valid_labels[key] = data[i + j]
            continue
        if j<target:#set first R words
            valid_examples[key][j] = data[i + j]
        else:#the next R words will be offset by 1 in the vector
            valid_examples[key][j-1] = data[i + j]
   
#print(valid_examples)
#print(valid_labels)

with graph.as_default():

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size,cbow_r*2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)

    # Variables.
    embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                             stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))

    global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
    decay_learning_rate = tf.train.exponential_decay(0.01, global_step, 1000, 0.96)
    
    # Model.
    # Look up embeddings for inputs.
   #train_dataset_reshaped = tf.reshape(train_dataset,(batch_size,embedding_size * cbow_r))
    #embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    #embed = tf.reshape(embed, (batch_size,-1))
    embed = None
    for i in range(2*cbow_r):
        embed_batch = tf.nn.embedding_lookup( embeddings , train_dataset[:,i])
        emb_x,emb_y = embed_batch.get_shape().as_list()
        
        if embed is None:
            print('embed is None, hence reshaping  from %s to  (%s,%s)' %(embed_batch.get_shape(), emb_x, emb_y) )
            embed = tf.reshape(embed_batch, [emb_x, emb_y, 1])
        else:
            print('embed is not None, hence  concating earlier embed %s with current embed_batch'\
                      %(embed.get_shape()) )
            embed = tf.concat([embed,tf.reshape(embed_batch,[emb_x,emb_y,1])],2)
            
    embed =  tf.reduce_mean(embed,2,keepdims=False)

    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer()

    train_op = optimizer.minimize(loss, global_step = global_step)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
    normalized_embeddings = embeddings / norm
    
    #valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    #valid_embeddings = tf.reshape(valid_embeddings, (valid_size,-1))
    
    valid_embeddings = None
    for i in range(2*cbow_r):
        valid_embeddings_batch = tf.nn.embedding_lookup( embeddings , valid_dataset[:,i])
        emb_x,emb_y = valid_embeddings_batch.get_shape().as_list()
        
        if valid_embeddings is None:
            print('valid_embeddings is None, hence reshaping  from %s to  (%s,%s)' 
                  % (valid_embeddings_batch.get_shape(), emb_x, emb_y) )
            valid_embeddings = tf.reshape(valid_embeddings_batch, [emb_x, emb_y, 1])
        else:
            print('valid_embeddings is not None, hence  concating earlier embed %s with current embed_batch'\
                      %(valid_embeddings.get_shape()) )
            valid_embeddings = tf.concat([valid_embeddings,tf.reshape(valid_embeddings_batch,[emb_x,emb_y,1])],2)
    
    valid_embeddings =  tf.reduce_mean(valid_embeddings,2,keepdims=False)
    
    predictions = tf.nn.softmax(tf.matmul(valid_embeddings, tf.transpose(softmax_weights)) + softmax_biases)
    #logits = tf.matmul(valid_embeddings, tf.transpose(softmax_weights))
    #logits = tf.nn.bias_add(logits, softmax_biases)

    
    #valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    #similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     509                 as_ref=input_arg.is_ref,
# --> 510                 preferred_dtype=default_dtype)
#     511           except TypeError as err:
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in internal_convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, ctx)
#    1103     if ret is None:
# -> 1104       ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1105
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _TensorTensorConversionFunction(t, dtype, name, as_ref)
#     946         "Tensor conversion requested dtype %s for Tensor with dtype %s: %r" %
# --> 947         (dtype.name, t.dtype.name, str(t)))
#     948   return t
#
# ValueError: Tensor conversion requested dtype int32 for Tensor with dtype float64: 'Tensor("ExponentialDecay_2/truediv:0", shape=(), dtype=float64)'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-6541b76a220f> in <module>()
#      41
#      42     global_step = tf.Variable(0, trainable=False)  # count the number of steps taken.
# ---> 43     decay_learning_rate = tf.train.exponential_decay(1, global_step, 1000, 0.96)
#      44
#      45     # Model.
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/training/learning_rate_decay.py in exponential_decay(learning_rate, global_step, decay_steps, decay_rate, staircase, name)
#     103       p = math_ops.floor(p)
#     104     return math_ops.multiply(
# --> 105         learning_rate, math_ops.pow(decay_rate, p), name=name)
#     106
#     107
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py in pow(x, y, name)
#     575   """
#     576   with ops.name_scope(name, "Pow", [x]) as name:
# --> 577     return gen_math_ops._pow(x, y, name=name)
#     578
#     579
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/ops/gen_math_ops.py in _pow(x, y, name)
#    5006   if _ctx is None or not _ctx._eager_context.is_eager:
#    5007     _, _, _op = _op_def_lib._apply_op_helper(
# -> 5008         "Pow", x=x, y=y, name=name)
#    5009     _result = _op.outputs[:]
#    5010     _inputs_flat = _op.inputs
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     544                   "%s type %s of argument '%s'." %
#     545                   (prefix, dtypes.as_dtype(attrs[input_arg.type_attr]).name,
# --> 546                    inferred_from[input_arg.type_attr]))
#     547
#     548           types = [values.dtype]
#
# TypeError: Input 'y' of 'Pow' Op has type float64 that does not match type int32 of argument 'x'.

# %%
with tf.Session(graph=graph) as session:
    params = tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0)
    ids = tf.constant([0,2,3,4])
    embed = tf.nn.embedding_lookup(params,ids).eval()
    print(embed[0][0]+embed[1][0]+embed[2][0]+embed[3][0])
    embed = tf.reduce_mean(embed, 0, keepdims=False)
    print(embed)
    print(embed.shape)
# Out:
# 0.8401964
# Tensor("Mean_19:0", shape=(128,), dtype=float32)
# (128,)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_cow(batch_size, cbow_r)
        
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        
        _, l = session.run([train_op, loss], feed_dict=feed_dict)
        
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
            
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            pred = predictions.eval()
            for j in range(0,valid_examples.shape[0]):
                print('    valid_examples ',j,': ', [reverse_dictionary[bi] for bi in valid_examples[:][j]], 
                      ':---------',reverse_dictionary[np.argmax(pred[j])],';------:', reverse_dictionary[valid_labels[j]])
    final_embeddings = normalized_embeddings.eval()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-11d4598b4f7c> in <module>()
#       2
#       3 with tf.Session(graph=graph) as session:
# ----> 4     tf.global_variables_initializer().run()
#       5     print('Initialized')
#       6     average_loss = 0
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in run(self, feed_dict, session)
#    2375         none, the default session will be used.
#    2376     """
# -> 2377     _run_using_default_session(self, feed_dict, self.graph, session)
#    2378
#    2379 _gradient_registry = registry.Registry("gradient")
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _run_using_default_session(operation, feed_dict, graph, session)
#    5213                        "the operation's graph is different from the session's "
#    5214                        "graph.")
# -> 5215   session.run(operation, feed_dict)
#    5216
#    5217
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     898     try:
#     899       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 900                          run_metadata_ptr)
#     901       if run_metadata:
#     902         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1133     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1134       results = self._do_run(handle, final_targets, final_fetches,
# -> 1135                              feed_dict_tensor, options, run_metadata)
#    1136     else:
#    1137       results = []
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1314     if handle is None:
#    1315       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1316                            run_metadata)
#    1317     else:
#    1318       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/Other/Virtualenvs/jupyter3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __init__(self, node_def, op, message)
#     330   """
#     331
# --> 332   def __init__(self, node_def, op, message):
#     333     """Creates a `ResourceExhaustedError`."""
#     334     super(ResourceExhaustedError, self).__init__(node_def, op, message,
#
# KeyboardInterrupt:
